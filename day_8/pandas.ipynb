# %% [markdown]
# # ***1. How to find the version***

# %%
# %pip install pandas
import pandas as pd # type: ignore
pd.__version__
# Out:
# Requirement already satisfied: pandas in c:\users\pc\miniconda3\envs\python_eda\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pc\miniconda3\envs\python_eda\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pc\miniconda3\envs\python_eda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\miniconda3\envs\python_eda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pc\miniconda3\envs\python_eda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pc\miniconda3\envs\python_eda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# '2.3.0'

# %%
# another way
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : 2cc37625532045f4ac55b27176454bbbc9baf213
# python                : 3.13.2
# python-bits           : 64
# OS                    : Windows
# OS-release            : 10
# Version               : 10.0.19045
# machine               : AMD64
# processor             : Intel64 Family 6 Model 94 Stepping 3, GenuineIntel
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : English_Pakistan.1252
#
# pandas                : 2.3.0
# numpy                 : 2.3.0
# pytz                  : 2025.2
# dateutil              : 2.9.0.post0
# pip                   : 25.0
# Cython                : None
# sphinx                : None
# IPython               : 9.0.0
# adbc-driver-postgresql: None
# adbc-driver-sqlite    : None
# bs4                   : None
# blosc                 : None
# bottleneck            : None
# dataframe-api-compat  : None
# fastparquet           : None
# fsspec                : None
# html5lib              : None
# hypothesis            : None
# gcsfs                 : None
# jinja2                : None
# lxml.etree            : None
# matplotlib            : None
# numba                 : None
# numexpr               : None
# odfpy                 : None
# openpyxl              : None
# pandas_gbq            : None
# psycopg2              : None
# pymysql               : None
# pyarrow               : None
# pyreadstat            : None
# pytest                : None
# python-calamine       : None
# pyxlsb                : None
# s3fs                  : None
# scipy                 : None
# sqlalchemy            : None
# tables                : None
# tabulate              : None
# xarray                : None
# xlrd                  : None
# xlsxwriter            : None
# zstandard             : None
# tzdata                : 2025.2
# qtpy                  : None
# pyqt5                 : None

# %% [markdown]
# # ***2. Make a dataframe***

# %% [markdown]
# ## ***Dataframe:***
#  > - dataframe is a two dimensional data structure.
#  > - It contains ***rows and columns***.
#  > - dataframe is **created by using dictionary**.
# ## ***Dictionary:***
# > - dictionary is a ***key-value pair***.
# > - dictionary is created by using **curly braces { }**.
# > - dictionary is created by using ***key and value***.\
# >       1. " ***key*** " means column name\
# >       2. " ***value*** " means column data.

# %%
df = pd.DataFrame({'Index' : [1, 2, 3, 4, 5], 'Name' : ['John', 'Paul', 'George', 'Ringo', 'Pete'], 'Marks' : [60, 70, 80, 90, 100]})
df
# Out:
#    Index    Name  Marks
# 0      1    John     60
# 1      2    Paul     70
# 2      3  George     80
# 3      4   Ringo     90
# 4      5    Pete    100

# %% [markdown]
# # ***3. Make dataframe using numpy***

# %% [markdown]
# make a dataframe using numpy
# > - import numpy as np
# > - numpy used to make a dataframe by using array
# > - array is used to make a dataframe
# > -
