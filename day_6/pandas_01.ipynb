# %% [markdown]
# # ***How to import dataset in python using pandas library***
# Written by : NOOR UL NISA \
# Date: 07 Sep 2024\
# Email ID: 766noornisa@gmail.com

# %% [markdown]
# ## ***Step# 1: Importing libraries***
# - In this step, we will give a nickname to pandas as pd
# - " Import " word is used to import the library
# - " as " word is used to give a nickname to the library

# %%
import pandas as pd

# %% [markdown]
# ## ***Step-2: Impororting/reading dataset***
# >1. Write the nickname of the library.
# >2. Type "."
# >3. After type ".", all commends of this library will be shown.
# >4. Select the "read_excel()" word.
# >5. Type the Excel file name in double quotes with the extension in ().
#     - OR Write the path of file in (), if we want to read the file in the same/other folder.

# %%
pd.read_excel("pandas_01_day6.xlsx")
# Out:
#    Height  Weight Favourite_Dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao
# ..    ...     ...            ...
# 82    5.4      55          Pasta
# 83    5.9      75  Karahi Ghosht
# 84    5.4      61        Biryani
# 85    6.2      68  Chicken Pulao
# 86    5.1      96        Biryani
#
# [87 rows x 3 columns]

# %% [markdown]
# # ***Step-3: Name of the dataset:***
# >- we cannot use the dataset if we don't give a name to the dataset
# >- Variable means assign a name.
# >- write a variable in which dataset is store e.g. " df "
# >- df means data frame.

# %%
df = pd.read_excel("pandas_01_day6.xlsx")

# is dataset showed in the output cell?
# Ans: NO

# %% [markdown]
# # ***Step-4: Print the dataset:***
# >-  After assiging a variable to the dataset, we need to print this variable.

# %%
print(df)

# now data is print in output.
# Out:
#    Height  Weight Favourite_Dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao
# ..    ...     ...            ...
# 82    5.4      55          Pasta
# 83    5.9      75  Karahi Ghosht
# 84    5.4      61        Biryani
# 85    6.2      68  Chicken Pulao
# 86    5.1      96        Biryani
#
# [87 rows x 3 columns]

# %% [markdown]
# # ***Step-5: Dataset info/parts:***
# ## *Dataset includes:*
#         1. Dataset parts
#         2. Dataset info
# ## ***5.1 Dataset Parts:***
# > There are three parts in the dataset.
# >   1. Head
# >   2. Tail
# >   3. Shape
# ## ***5.2 Dataset Info:***
#
#
# > Dataset information include:
# > - total no. of rows
# > - total no. of columns
# > - total no. of non null values in each column
# > - data type of each column
# > - memory usage of each column
# > - index type
# > - memory usage of the dataset.

# %% [markdown]
# ## ***5.1 Dataset Parts***
# ### ***1. Head:***
# >- ***head()*** command is used to show the first five rows of the dataset.
# >- Write the dataset name "df" and type "."
# >- After type ".", all commends of this library will be shown.
# >- Select the "head()" word.
# #### ***By default no. of rows:***
# >- First five rows will be shown from index 0 to 4.
# >- In python, index(serial no.) starts from 0.
# #### ***Specific no. of rows:***
# >- Type the number of rows you want to show in ().

# %%
# head() command is used to show the first five rows of the dataset.
# by Default head() shows first five rows.
df.head()
# Out:
#   Height  Weight Favourite_Dish
# 0    5.8     101  Chicken Pulao
# 1    6.2      92        Biryani
# 2    5.9      62  Karahi Ghosht
# 3    5.9      95  Chicken Pulao
# 4    5.9      55  Chicken Pulao

# %%
# For specific no. of rows, type the numbers of rows you want to show in ().

df.head(3)
# Out:
#   Height  Weight Favourite_Dish
# 0    5.8     101  Chicken Pulao
# 1    6.2      92        Biryani
# 2    5.9      62  Karahi Ghosht

# %% [markdown]
# ### ***2. Tail:***
#
# > - tail() command is used to show the last five rows of the dataset.

# %%
df.tail()
# Out:
#    Height  Weight Favourite_Dish
# 82    5.4      55          Pasta
# 83    5.9      75  Karahi Ghosht
# 84    5.4      61        Biryani
# 85    6.2      68  Chicken Pulao
# 86    5.1      96        Biryani

# %% [markdown]
# ### ***3. Shape:***
#
# >- "shape" means look of the dataset.
#
# >- Type "df.shape"
#
# >- "shape" is used to show the total number of rows and columns in the dataset.
#
# >- Always no. of rows is written first and second no. of columns.
#
# >- output (87,3)

# %%
df.shape
# Out:
# (87, 3)

# %% [markdown]
# ## ***5.2 Dataset Info***
# >   - info() command is used to show the information of the dataset.
# >   - Select the "info()" word.
# >   - information of the dataset will be shown in the output cell.

# %%
df.info()

# Dataset information include:
    # > - total no. of rows
    # > - total no. of columns
    # > - total no. of non null values in each column
    # > - data type of each column
    # > - memory usage of each column
    # > - index type
    # > - memory usage of the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Height          87 non-null     object
#  1   Weight          87 non-null     int64
#  2   Favourite_Dish  87 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.2+ KB

# %% [markdown]
# ## ***Why we write some command with ( ) and some command without ( )?***
# ### Ans:
#
# ### ***Object:***
# > - Commands Without ( ) is called ***Object***.
# > - Commands without parenthesis () is an object of that function which can be passed as an argument and later be called by appending () to it.
# #### ***For Example:***
# > - hello refers to the function object
#
# ### ***Function:***
# > - Commands With ( ) is called ***Funcion***.
# > - function with parenthesis () is actually calling (invoke) that function
# #### ***For Example:***
# > - hello() calls the function itself.

# %%
pip install xelatex
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement xelatex (from versions: none)
# ERROR: No matching distribution found for xelatex

# %%
pip install --upgrade pip
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.8 MB 156.1 kB/s eta 0:00:12
#    - -------------------------------------- 0.1/1.8 MB 156.1 kB/s eta 0:00:12
# ...
